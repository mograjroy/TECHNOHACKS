# %% [markdown]
# # Task 1 -- Perform Data Cleaning

# %% [markdown]
# Clean a dataset by removing missing values
# and outliers

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("test.csv")
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df.shape
# Out:
# (418, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
df.describe(include = 'all')
# Out:
#         PassengerId      Pclass              Name   Sex         Age  \
# count    418.000000  418.000000               418   418  332.000000
# unique          NaN         NaN               418     2         NaN
# top             NaN         NaN  Kelly, Mr. James  male         NaN
# freq            NaN         NaN                 1   266         NaN
# mean    1100.500000    2.265550               NaN   NaN   30.272590
# std      120.810458    0.841838               NaN   NaN   14.181209
# min      892.000000    1.000000               NaN   NaN    0.170000
# 25%      996.250000    1.000000               NaN   NaN   21.000000
# 50%     1100.500000    3.000000               NaN   NaN   27.000000
# 75%     1204.750000    3.000000               NaN   NaN   39.000000
# max     1309.000000    3.000000               NaN   NaN   76.000000
#
#              SibSp       Parch        Ticket        Fare            Cabin  \
# count   418.000000  418.000000  4.160000e+02  417.000000               91
# unique         NaN         NaN           NaN         NaN               76
# top            NaN         NaN           NaN         NaN  B57 B59 B63 B66
# freq           NaN         NaN           NaN         NaN                3
# mean      0.447368    0.392344  4.538490e+04   35.627188              NaN
# std       0.896760    0.981429  2.293306e+05   55.907576              NaN
# min       0.000000    0.000000  2.500000e+01    0.000000              NaN
# 25%       0.000000    0.000000  1.369000e+03    7.895800              NaN
# 50%       0.000000    0.000000  5.333000e+03   14.454200              NaN
# 75%       1.000000    0.000000  3.460925e+04   31.500000              NaN
# max       8.000000    9.000000  2.310129e+06  512.329200              NaN
#
#        Embarked
# count       418
# unique        3
# top           S
# freq        270
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %% [markdown]
# # Missing values treatment

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           2
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df["Age"]

# %%
# check datatype
df.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
pd.set_option('display.max_rows',None)

# %%
# To change Datatype 

df[['Ticket']] = df[['Ticket']].apply(pd.to_numeric)
print(df.dtypes)
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket         float64
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.Age.fillna(30,inplace=True)

# %%
# Remove extra specific character
df["Ticket"] = [x.strip("A-Z") for x in df["Ticket"]]

# Remove all extra character
df['Ticket'] = df['Ticket'].str.replace('\D', '', regex=True)

# %%
df.head(10)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S
# 5  14.0      0      0     7538   9.2250   NaN        S
# 6  30.0      0      0   330972   7.6292   NaN        Q
# 7  26.0      1      1   248738  29.0000   NaN        S
# 8  18.0      0      0     2657   7.2292   NaN        C
# 9  21.0      2      0   448871  24.1500   NaN        S

# %% [markdown]
# # Detect outlier

# %%
# check outlier
sns.displot(df["Age"])

# %%
# Here we can see the outlier, now will try to removie or replce acording the data.
sns.boxplot(x='Sex',y='Age',data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %% [markdown]
# # Treat outlier

# %%
high_boud = df["Age"].quantile(.95)
high_boud
# Out:
# 57.0

# %%
low_boud = df["Age"].quantile(0.5)
low_boud

# %%
df[df["Age"]<high_boud]
df.head(10)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 0  34.5      0      0   33091.0   7.8292   NaN        Q
# 1  47.0      1      0   36327.0   7.0000   NaN        S
# 2  62.0      0      0   24027.0   9.6875   NaN        Q
# 3  27.0      0      0   31515.0   8.6625   NaN        S
# 4  22.0      1      1  310129.0  12.2875   NaN        S
# 5  14.0      0      0     753.0   9.2250   NaN        S
# 6  30.0      0      0   33097.0   7.6292   NaN        Q
# 7  26.0      1      1   24873.0  29.0000   NaN        S
# 8  18.0      0      0     265.0   7.2292   NaN        C
# 9  21.0      2      0   44887.0  24.1500   NaN        S

# %%
show=df[df["Age"]<high_boud]
sns.boxplot(x="Sex",y="Age",data=show)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
df1=df[df['Age']<max]
sns.boxplot(y='Age',data=df1)
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
mult_conditions = df[(df['Sex'] == 'female') & (df['Age'] > 50)]
mult_conditions.head()
# Out:
#      PassengerId  Pclass                                               Name  \
# 48           940       1    Bucknell, Mrs. William Robert (Emma Eliza Ward)
# 69           961       1                Fortune, Mrs. Mark (Mary McDougald)
# 77           969       1  Cornell, Mrs. Robert Clifford (Malvina Helen L...
# 96           988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 114         1006       1             Straus, Mrs. Isidor (Rosalie Ida Blun)
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 48   female  60.0      0      0     11813   76.2917          D15        C
# 69   female  60.0      1      4     19950  263.0000  C23 C25 C27        S
# 77   female  55.0      2      0     11770   25.7000         C101        S
# 96   female  76.0      1      0     19877   78.8500          C46        S
# 114  female  63.0      1      0  PC 17483  221.7792      C55 C57        S

# %%
df2=df[["Sex","Age"]]
df2.head()
# Out:
#       Sex   Age
# 0    male  34.5
# 1  female  47.0
# 2    male  62.0
# 3    male  27.0
# 4  female  22.0

# %%
df["Age"].describe()
# Out:
# count    332.000000
# mean      30.272590
# std       14.181209
# min        0.170000
# 25%       21.000000
# 50%       27.000000
# 75%       39.000000
# max       76.000000
# Name: Age, dtype: float64

# %%
df[df["Age"]<max]
# Out:
#      PassengerId  Pclass                                             Name  \
# 0            892       3                                 Kelly, Mr. James
# 1            893       3                 Wilkes, Mrs. James (Ellen Needs)
# 3            895       3                                 Wirz, Mr. Albert
# 4            896       3     Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                       Svensson, Mr. Johan Cervin
# ..           ...     ...                                              ...
# 409         1301       3                        Peacock, Miss. Treasteall
# 411         1303       1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412         1304       3                   Henriksson, Miss. Jenny Lovisa
# 414         1306       1                     Oliva y Ocana, Dona. Fermina
# 415         1307       3                     Saether, Mr. Simon Sivertsen
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# 5      male  14.0      0      0                7538    9.2250   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 409  female   3.0      1      1  SOTON/O.Q. 3101315   13.7750   NaN        S
# 411  female  37.0      1      0               19928   90.0000   C78        Q
# 412  female  28.0      0      0              347086    7.7750   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
#
# [313 rows x 11 columns]

# %%
min=df["Age"].quantile(0.5)
min
# Out:
# 27.0

# %%
max=df["Age"].quantile(0.95)
max
# Out:
# 57.0
